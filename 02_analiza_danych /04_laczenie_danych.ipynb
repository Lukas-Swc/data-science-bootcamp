# %% [markdown]
# <a href="https://colab.research.google.com/github/Lukas-Swc/data-science-bootcamp/blob/main/02_analiza_danych%20/04_laczenie_danych.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Pandas
# Strona biblioteki: [https://pandas.pydata.org/](https://pandas.pydata.org/)
# Dokumentacja: [https://pandas.pydata.org/pandas-docs/stable/](https://pandas.pydata.org/pandas-docs/stable/)
#
# Podstawowa biblioteka do analizy danych w języku Python.
#
# Aby zainstalować bibliotekę Pandas użyj polecenia poniżej:
# ```
# pip install pandas
# ```
# ### Spis treści:
# 1. [Import bibliotek](#a1)
# 2. [Wczytanie danych](#a2)
# 3. [Preprocessing](#a3)
# 4. [Konkatenacja danych](#a4)
# 5. [Metoda append()](#a5)

# %% [markdown]
# ### <a name='a1'></a> Import bibliotek

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# ### <a name='a2'></a> Wczytanie danych

# %%
def fetch_financial_data(company='AMZN'):
    """
    This function fetch stock market quotations.
    """
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

apple = fetch_financial_data('AAPL')
amazon = fetch_financial_data('AMZN')
google = fetch_financial_data('GOOGL')
palantire = fetch_financial_data('PLTR')

# %%
palantire.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1101 entries, 2025-02-18 to 2020-09-30
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1101 non-null   float64
#  1   High    1101 non-null   float64
#  2   Low     1101 non-null   float64
#  3   Close   1101 non-null   float64
#  4   Volume  1101 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 51.6 KB

# %%
apple.head()
# Out:
#               Open      High     Low   Close      Volume
# Date
# 2025-02-18  243.91  245.1800  241.84  244.47  48822491.0
# 2025-02-14  241.25  245.5500  240.99  244.60  40896227.0
# 2025-02-13  236.91  242.3399  235.57  241.53  53614054.0
# 2025-02-12  231.20  236.9600  230.68  236.87  45243292.0
# 2025-02-11  228.20  235.2300  228.13  232.62  53718362.0

# %% [markdown]
# ### <a name='a3'></a> Preprocessing

# %%
apple.columns = ['apple_' + col.lower() for col in apple.columns]
apple.columns
# Out:
# Index(['apple_open', 'apple_high', 'apple_low', 'apple_close', 'apple_volume'], dtype='object')

# %%
amazon.columns = ['amazon_' + col.lower() for col in amazon.columns]
google.columns = ['google_' + col.lower() for col in google.columns]
palantire.columns = ['palantire_' + col.lower() for col in palantire.columns]

# %%
print(amazon.columns)
print(google.columns)
print(palantire.columns)
# Out:
# Index(['amazon_open', 'amazon_high', 'amazon_low', 'amazon_close',
#        'amazon_volume'],
#       dtype='object')
# Index(['google_open', 'google_high', 'google_low', 'google_close',
#        'google_volume'],
#       dtype='object')
# Index(['palantire_open', 'palantire_high', 'palantire_low', 'palantire_close',
#        'palantire_volume'],
#       dtype='object')

# %%
apple.head()
# Out:
#             apple_open  apple_high  apple_low  apple_close  apple_volume
# Date
# 2025-02-18      243.91    245.1800     241.84       244.47    48822491.0
# 2025-02-14      241.25    245.5500     240.99       244.60    40896227.0
# 2025-02-13      236.91    242.3399     235.57       241.53    53614054.0
# 2025-02-12      231.20    236.9600     230.68       236.87    45243292.0
# 2025-02-11      228.20    235.2300     228.13       232.62    53718362.0

# %% [markdown]
# ### <a name='a4'></a> Konkatenacja danych

# %%
df = pd.concat(objs=[apple, amazon, google, palantire], axis=1)
df
# Out:
#             apple_open  apple_high  apple_low  apple_close  apple_volume  \
# Date
# 2020-02-21     77.4936     77.9350    75.5163      76.1375  1.333251e+08
# 2020-02-24     72.2993     73.9785    70.3439      72.5216  2.283957e+08
# 2020-02-25     73.1953     73.5795    69.5913      70.0634  2.371104e+08
# 2020-02-26     69.6889     72.4514    69.6820      71.1763  2.042588e+08
# 2020-02-27     68.3695     69.5606    66.3863      66.5235  3.295520e+08
# ...                ...         ...        ...          ...           ...
# 2025-02-11    228.2000    235.2300   228.1300     232.6200  5.371836e+07
# 2025-02-12    231.2000    236.9600   230.6800     236.8700  4.524329e+07
# 2025-02-13    236.9100    242.3399   235.5700     241.5300  5.361405e+07
# 2025-02-14    241.2500    245.5500   240.9900     244.6000  4.089623e+07
# 2025-02-18    243.9100    245.1800   241.8400     244.4700  4.882249e+07
#
#             amazon_open  amazon_high  amazon_low  amazon_close  amazon_volume  \
# google_low       1255.00      120.77       33.34       50.44       95.37
# google_close     1255.00      122.16       33.55       52.71       96.96
# google_volume    1255.00 32924064.15 14548502.11  9312760.00 23381845.50
# palantire_open   1101.00       21.90       16.85        5.84       10.32
# palantire_high   1101.00       22.52       17.38        6.17       10.76
# palantire_low    1101.00       21.33       16.45        5.84        9.99
# palantire_close  1101.00       21.96       17.03        6.00       10.43
# palantire_volume 1101.00 56014508.39 41292748.78  9126352.00 32608983.00
#
#                          50%          75%          max
# apple_open            153.76       181.13       258.19
# apple_high            155.91       182.41       260.10
# apple_low             151.93       179.52       257.63
# apple_close           154.12       181.03       259.02
# apple_volume     75666406.34 105632899.85 438797128.15
# amazon_open           155.85       172.03       239.01
# amazon_high           157.82       173.69       242.52
# amazon_low            153.90       169.96       238.03
# amazon_close          155.51       172.05       242.06
# amazon_volume    59179620.00  80574540.00 272661720.00
# google_open           122.09       142.93       203.39
# google_high           123.09       143.87       207.05
# google_low            121.06       141.20       202.81
# google_close          122.27       142.53       206.38
# google_volume    29150360.00  37580956.50 123199220.00
# palantire_open         18.66        25.00       120.94
# palantire_high         19.12        25.59       125.00
# palantire_low          18.10        24.35       118.43
# palantire_close        18.69        25.00       124.62
# palantire_volume 44243214.00  63834517.00 450290538.00

# %%
df.corr()
# Out:
#                   apple_open  apple_high  apple_low  apple_close  \
# apple_open              1.00        1.00       1.00         1.00
# apple_high              1.00        1.00       1.00         1.00
# apple_low               1.00        1.00       1.00         1.00
# apple_close             1.00        1.00       1.00         1.00
# apple_volume           -0.64       -0.63      -0.65        -0.64
# amazon_open             0.54        0.54       0.54         0.54
# amazon_high             0.54        0.54       0.54         0.54
# amazon_low              0.54        0.54       0.54         0.54
# amazon_close            0.54        0.54       0.54         0.54
# amazon_volume          -0.59       -0.58      -0.59        -0.59
# google_open             0.90        0.90       0.90         0.90
# google_high             0.90        0.90       0.90         0.90
# google_low              0.90        0.90       0.90         0.90
# google_close            0.90        0.90       0.90         0.90
# google_volume          -0.33       -0.33      -0.34        -0.34
# palantire_open          0.60        0.60       0.60         0.60
# palantire_high          0.59        0.59       0.59         0.59
# palantire_low           0.60        0.60       0.60         0.61
# palantire_close         0.60        0.60       0.60         0.60
# palantire_volume        0.12        0.12       0.12         0.12
#
#                   apple_volume  amazon_open  amazon_high  amazon_low  \
# apple_open               -0.64         0.54         0.54        0.54
# apple_high               -0.63         0.54         0.54        0.54
# apple_low                -0.65         0.54         0.54        0.54
# apple_close              -0.64         0.54         0.54        0.54
# apple_volume              1.00        -0.23        -0.23       -0.24
# amazon_open              -0.23         1.00         1.00        1.00
# amazon_high              -0.23         1.00         1.00        1.00
# amazon_low               -0.24         1.00         1.00        1.00
# amazon_close             -0.23         1.00         1.00        1.00
# amazon_volume             0.68        -0.37        -0.36       -0.38
# google_open              -0.58         0.71         0.71        0.71
# google_high              -0.58         0.71         0.71        0.71
# google_low               -0.58         0.71         0.71        0.72
# google_close             -0.58         0.71         0.71        0.71
# google_volume             0.50        -0.29        -0.28       -0.30
# palantire_open           -0.23         0.79         0.79        0.79
# palantire_high           -0.23         0.79         0.79        0.79
# palantire_low            -0.24         0.79         0.79        0.79
# palantire_close          -0.23         0.79         0.79        0.79
# palantire_volume          0.09         0.17         0.17        0.17
#
#                   amazon_close  amazon_volume  google_open  google_high  \
# apple_open                0.54          -0.59         0.90         0.90
# apple_high                0.54          -0.58         0.90         0.90
# apple_low                 0.54          -0.59         0.90         0.90
# apple_close               0.54          -0.59         0.90         0.90
# apple_volume             -0.23           0.68        -0.58        -0.58
# amazon_open               1.00          -0.37         0.71         0.71
# amazon_high               1.00          -0.36         0.71         0.71
# amazon_low                1.00          -0.38         0.71         0.71
# amazon_close              1.00          -0.37         0.71         0.71
# amazon_volume            -0.37           1.00        -0.57        -0.57
# google_open               0.71          -0.57         1.00         1.00
# google_high               0.71          -0.57         1.00         1.00
# google_low                0.71          -0.58         1.00         1.00
# google_close              0.71          -0.57         1.00         1.00
# google_volume            -0.29           0.58        -0.34        -0.33
# palantire_open            0.79          -0.33         0.66         0.66
# palantire_high            0.79          -0.33         0.66         0.66
# palantire_low             0.79          -0.34         0.67         0.67
# palantire_close           0.79          -0.33         0.66         0.66
# palantire_volume          0.17          -0.01         0.08         0.09
#
#                   google_low  google_close  google_volume  palantire_open  \
# apple_open              0.90          0.90          -0.33            0.60
# apple_high              0.90          0.90          -0.33            0.60
# apple_low               0.90          0.90          -0.34            0.60
# apple_close             0.90          0.90          -0.34            0.60
# apple_volume           -0.58         -0.58           0.50           -0.23
# amazon_open             0.71          0.71          -0.29            0.79
# amazon_high             0.71          0.71          -0.28            0.79
# amazon_low              0.72          0.71          -0.30            0.79
# amazon_close            0.71          0.71          -0.29            0.79
# amazon_volume          -0.58         -0.57           0.58           -0.33
# google_open             1.00          1.00          -0.34            0.66
# google_high             1.00          1.00          -0.33            0.66
# google_low              1.00          1.00          -0.35            0.66
# google_close            1.00          1.00          -0.35            0.66
# google_volume          -0.35         -0.35           1.00           -0.14
# palantire_open          0.66          0.66          -0.14            1.00
# palantire_high          0.66          0.66          -0.14            1.00
# palantire_low           0.67          0.67          -0.15            1.00
# palantire_close         0.66          0.66          -0.14            1.00
# palantire_volume        0.08          0.09           0.07            0.25
#
#                   palantire_high  palantire_low  palantire_close  \
# apple_open                  0.59           0.60             0.60
# apple_high                  0.59           0.60             0.60
# apple_low                   0.59           0.60             0.60
# apple_close                 0.59           0.61             0.60
# apple_volume               -0.23          -0.24            -0.23
# amazon_open                 0.79           0.79             0.79
# amazon_high                 0.79           0.79             0.79
# amazon_low                  0.79           0.79             0.79
# amazon_close                0.79           0.79             0.79
# amazon_volume              -0.33          -0.34            -0.33
# google_open                 0.66           0.67             0.66
# google_high                 0.66           0.67             0.66
# google_low                  0.66           0.67             0.66
# google_close                0.66           0.67             0.66
# google_volume              -0.14          -0.15            -0.14
# palantire_open              1.00           1.00             1.00
# palantire_high              1.00           1.00             1.00
# palantire_low               1.00           1.00             1.00
# palantire_close             1.00           1.00             1.00
# palantire_volume            0.27           0.24             0.26
#
#                   palantire_volume
# apple_open                    0.12
# apple_high                    0.12
# apple_low                     0.12
# apple_close                   0.12
# apple_volume                  0.09
# amazon_open                   0.17
# amazon_high                   0.17
# amazon_low                    0.17
# amazon_close                  0.17
# amazon_volume                -0.01
# google_open                   0.08
# google_high                   0.09
# google_low                    0.08
# google_close                  0.09
# google_volume                 0.07
# palantire_open                0.25
# palantire_high                0.27
# palantire_low                 0.24
# palantire_close               0.26
# palantire_volume              1.00

# %%
df.columns
# Out:
# Index(['apple_open', 'apple_high', 'apple_low', 'apple_close', 'apple_volume',
#        'amazon_open', 'amazon_high', 'amazon_low', 'amazon_close',
#        'amazon_volume', 'google_open', 'google_high', 'google_low',
#        'google_close', 'google_volume', 'palantire_open', 'palantire_high',
#        'palantire_low', 'palantire_close', 'palantire_volume'],
#       dtype='object')

# %%
closes = [col for col in df.columns if col.endswith('close')]
closes
# Out:
# ['apple_close', 'amazon_close', 'google_close', 'palantire_close']

# %%
df[closes].corr()
# Out:
#                  apple_close  amazon_close  google_close  palantire_close
# apple_close             1.00          0.54          0.90             0.60
# amazon_close            0.54          1.00          0.71             0.79
# google_close            0.90          0.71          1.00             0.66
# palantire_close         0.60          0.79          0.66             1.00

# %%
volumes = [col for col in df.columns if col.endswith('close') or col.endswith('volume')]
volumes
# Out:
# ['apple_close',
#  'apple_volume',
#  'amazon_close',
#  'amazon_volume',
#  'google_close',
#  'google_volume',
#  'palantire_close',
#  'palantire_volume']

# %%
df[volumes].corr()
# Out:
#                   apple_close  apple_volume  amazon_close  amazon_volume  \
# apple_close              1.00         -0.64          0.54          -0.59
# apple_volume            -0.64          1.00         -0.23           0.68
# amazon_close             0.54         -0.23          1.00          -0.37
# amazon_volume           -0.59          0.68         -0.37           1.00
# google_close             0.90         -0.58          0.71          -0.57
# google_volume           -0.34          0.50         -0.29           0.58
# palantire_close          0.60         -0.23          0.79          -0.33
# palantire_volume         0.12          0.09          0.17          -0.01
#
#                   google_close  google_volume  palantire_close  \
# apple_close               0.90          -0.34             0.60
# apple_volume             -0.58           0.50            -0.23
# amazon_close              0.71          -0.29             0.79
# amazon_volume            -0.57           0.58            -0.33
# google_close              1.00          -0.35             0.66
# google_volume            -0.35           1.00            -0.14
# palantire_close           0.66          -0.14             1.00
# palantire_volume          0.09           0.07             0.26
#
#                   palantire_volume
# apple_close                   0.12
# apple_volume                  0.09
# amazon_close                  0.17
# amazon_volume                -0.01
# google_close                  0.09
# google_volume                 0.07
# palantire_close               0.26
# palantire_volume              1.00

# %% [markdown]
# ### <a name='a5'></a> Metoda append()

# %%
palantire.head()
# Out:
#             palantire_open  palantire_high  palantire_low  palantire_close  \
# Date
# 2025-02-18          120.94          125.00         118.43           124.62
# 2025-02-14          117.90          120.67         116.80           119.16
# 2025-02-13          117.31          118.39         115.15           117.91
# 2025-02-12          110.29          117.59         110.00           117.39
# 2025-02-11          116.50          118.66         112.10           112.62
#
#             palantire_volume
# Date
# 2025-02-18          84227164
# 2025-02-14          65528863
# 2025-02-13          60026970
# 2025-02-12          75316878
# 2025-02-11          94311705

# %%
palantire_6 = palantire[palantire.index.month == 6]
palantire_6
# Out:
#             palantire_open  palantire_high  palantire_low  palantire_close  \
# Date
# 2024-06-28           25.28           25.57          25.03            25.33
# 2024-06-27           24.10           25.40          24.05            25.22
# 2024-06-26           24.47           24.66          24.02            24.10
# 2024-06-25           24.16           24.63          23.92            24.56
# 2024-06-24           23.44           24.39          23.30            24.16
# ...                    ...             ...            ...              ...
# 2021-06-07           24.00           24.76          23.79            24.46
# 2021-06-04           23.71           24.49          23.50            24.03
# 2021-06-03           24.14           24.26          23.34            23.63
# 2021-06-02           23.02           24.84          22.82            24.45
# 2021-06-01           23.19           23.35          22.36            23.06
#
#             palantire_volume
# Date
# 2024-06-28          38886441
# 2024-06-27          37882859
# 2024-06-26          24331377
# 2024-06-25          29657245
# 2024-06-24          36477408
# ...                      ...
# 2021-06-07          49641037
# 2021-06-04          42537599
# 2021-06-03          48164194
# 2021-06-02          86473158
# 2021-06-01          52695506
#
# [83 rows x 5 columns]

# %%
palantire_7 = palantire[palantire.index.month == 7]
palantire_7
# Out:
#             palantire_open  palantire_high  palantire_low  palantire_close  \
# Date
# 2024-07-31           27.02           27.39          26.88            26.89
# 2024-07-30           27.25           27.44          25.89            26.37
# 2024-07-29           27.56           27.80          26.73            27.08
# 2024-07-26           27.00           27.34          26.77            27.18
# 2024-07-25           26.04           27.29          25.42            26.63
# ...                    ...             ...            ...              ...
# 2021-07-08           22.43           23.21          22.25            23.08
# 2021-07-07           24.23           24.26          22.72            22.89
# 2021-07-06           24.60           25.20          24.47            24.68
# 2021-07-02           25.00           25.34          24.33            24.44
# 2021-07-01           26.10           26.13          24.59            24.72
#
#             palantire_volume
# Date
# 2024-07-31          29111605
# 2024-07-30          31819905
# 2024-07-29          26038842
# 2024-07-26          27432224
# 2024-07-25          45474613
# ...                      ...
# 2021-07-08          34612558
# 2021-07-07          66937305
# 2021-07-06          28764530
# 2021-07-02          29529097
# 2021-07-01          55571523
#
# [83 rows x 5 columns]

# %%
palantire_6_7 = pd.concat([palantire_6, palantire_7])
palantire_6_7
# Out:
#             palantire_open  palantire_high  palantire_low  palantire_close  \
# Date
# 2024-06-28           25.28           25.57          25.03            25.33
# 2024-06-27           24.10           25.40          24.05            25.22
# 2024-06-26           24.47           24.66          24.02            24.10
# 2024-06-25           24.16           24.63          23.92            24.56
# 2024-06-24           23.44           24.39          23.30            24.16
# ...                    ...             ...            ...              ...
# 2021-07-08           22.43           23.21          22.25            23.08
# 2021-07-07           24.23           24.26          22.72            22.89
# 2021-07-06           24.60           25.20          24.47            24.68
# 2021-07-02           25.00           25.34          24.33            24.44
# 2021-07-01           26.10           26.13          24.59            24.72
#
#             palantire_volume
# Date
# 2024-06-28          38886441
# 2024-06-27          37882859
# 2024-06-26          24331377
# 2024-06-25          29657245
# 2024-06-24          36477408
# ...                      ...
# 2021-07-08          34612558
# 2021-07-07          66937305
# 2021-07-06          28764530
# 2021-07-02          29529097
# 2021-07-01          55571523
#
# [166 rows x 5 columns]
